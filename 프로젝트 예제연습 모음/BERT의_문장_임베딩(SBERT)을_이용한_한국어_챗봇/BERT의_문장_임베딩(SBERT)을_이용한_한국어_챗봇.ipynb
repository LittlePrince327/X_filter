# %%
pip install sentence_transformers
# Out:
# Collecting sentence_transformers
#   Downloading sentence-transformers-2.2.2.tar.gz (85 kB)
#      ---------------------------------------- 0.0/86.0 kB ? eta -:--:--
#      ---- ----------------------------------- 10.2/86.0 kB ? eta -:--:--
#      ------------------ ------------------- 41.0/86.0 kB 326.8 kB/s eta 0:00:01
#      -------------------------------------- 86.0/86.0 kB 694.6 kB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: transformers<5.0.0,>=4.6.0 in c:\users\gjaischool1\anaconda3\envs\deep_learning\lib\site-packages (from sentence_transformers) (4.34.0)
# Requirement already satisfied: tqdm in c:\users\gjaischool1\anaconda3\envs\deep_learning\lib\site-packages (from sentence_transformers) (4.66.1)
# Requirement already satisfied: torch>=1.6.0 in c:\users\gjaischool1\anaconda3\envs\deep_learning\lib\site-packages (from sentence_transformers) (2.1.0)
# Collecting torchvision (from sentence_transformers)
#   Obtaining dependency information for torchvision from https://files.pythonhosted.org/packages/cc/1b/d781261269b3d0a5da35feda8e0b5ca7d25f5d08945bc6fba809e8cb7cbc/torchvision-0.16.0-cp38-cp38-win_amd64.whl.metadata
#   Downloading torchvision-0.16.0-cp38-cp38-win_amd64.whl.metadata (6.6 kB)
# Requirement already satisfied: numpy in c:\users\gjaischool1\anaconda3\envs\deep_learning\lib\site-packages (from sentence_transformers) (1.24.3)
# Requirement already satisfied: scikit-learn in c:\users\gjaischool1\anaconda3\envs\deep_learning\lib\site-packages (from sentence_transformers) (1.3.0)
# Requirement already satisfied: scipy in c:\users\gjaischool1\anaconda3\envs\deep_learning\lib\site-packages (from sentence_transformers) (1.10.1)
# Collecting nltk (from sentence_transformers)
#   Downloading nltk-3.8.1-py3-none-any.whl (1.5 MB)
#      ---------------------------------------- 0.0/1.5 MB ? eta -:--:--
#      ------------ --------------------------- 0.5/1.5 MB 14.4 MB/s eta 0:00:01
#      ------------------------------ --------- 1.2/1.5 MB 14.8 MB/s eta 0:00:01
#      ---------------------------------------- 1.5/1.5 MB 12.0 MB/s eta 0:00:00
# Collecting sentencepiece (from sentence_transformers)
#   Downloading sentencepiece-0.1.99-cp38-cp38-win_amd64.whl (977 kB)
#      ---------------------------------------- 0.0/977.6 kB ? eta -:--:--
#      -------------------------- ---------- 706.6/977.6 kB 14.8 MB/s eta 0:00:01
#      ------------------------------------- 977.6/977.6 kB 15.4 MB/s eta 0:00:00
# Requirement already satisfied: huggingface-hub>=0.4.0 in c:\users\gjaischool1\anaconda3\envs\deep_learning\lib\site-packages (from sentence_transformers) (0.17.3)
# Requirement already satisfied: filelock in c:\users\gjaischool1\anaconda3\envs\deep_learning\lib\site-packages (from huggingface-hub>=0.4.0->sentence_transformers) (3.12.4)
# Requirement already satisfied: fsspec in c:\users\gjaischool1\anaconda3\envs\deep_learning\lib\site-packages (from huggingface-hub>=0.4.0->sentence_transformers) (2023.9.2)
# Requirement already satisfied: requests in c:\users\gjaischool1\anaconda3\envs\deep_learning\lib\site-packages (from huggingface-hub>=0.4.0->sentence_transformers) (2.31.0)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\gjaischool1\anaconda3\envs\deep_learning\lib\site-packages (from huggingface-hub>=0.4.0->sentence_transformers) (6.0.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\gjaischool1\anaconda3\envs\deep_learning\lib\site-packages (from huggingface-hub>=0.4.0->sentence_transformers) (4.5.0)
# Requirement already satisfied: packaging>=20.9 in c:\users\gjaischool1\anaconda3\envs\deep_learning\lib\site-packages (from huggingface-hub>=0.4.0->sentence_transformers) (23.1)
# Requirement already satisfied: sympy in c:\users\gjaischool1\anaconda3\envs\deep_learning\lib\site-packages (from torch>=1.6.0->sentence_transformers) (1.12)
# Requirement already satisfied: networkx in c:\users\gjaischool1\anaconda3\envs\deep_learning\lib\site-packages (from torch>=1.6.0->sentence_transformers) (3.1)
# Requirement already satisfied: jinja2 in c:\users\gjaischool1\anaconda3\envs\deep_learning\lib\site-packages (from torch>=1.6.0->sentence_transformers) (3.1.2)
# Requirement already satisfied: colorama in c:\users\gjaischool1\anaconda3\envs\deep_learning\lib\site-packages (from tqdm->sentence_transformers) (0.4.6)
# Requirement already satisfied: regex!=2019.12.17 in c:\users\gjaischool1\anaconda3\envs\deep_learning\lib\site-packages (from transformers<5.0.0,>=4.6.0->sentence_transformers) (2023.10.3)
# Requirement already satisfied: tokenizers<0.15,>=0.14 in c:\users\gjaischool1\anaconda3\envs\deep_learning\lib\site-packages (from transformers<5.0.0,>=4.6.0->sentence_transformers) (0.14.1)
# Requirement already satisfied: safetensors>=0.3.1 in c:\users\gjaischool1\anaconda3\envs\deep_learning\lib\site-packages (from transformers<5.0.0,>=4.6.0->sentence_transformers) (0.4.0)
# Collecting click (from nltk->sentence_transformers)
#   Obtaining dependency information for click from https://files.pythonhosted.org/packages/00/2e/d53fa4befbf2cfa713304affc7ca780ce4fc1fd8710527771b58311a3229/click-8.1.7-py3-none-any.whl.metadata
#   Downloading click-8.1.7-py3-none-any.whl.metadata (3.0 kB)
# Requirement already satisfied: joblib in c:\users\gjaischool1\anaconda3\envs\deep_learning\lib\site-packages (from nltk->sentence_transformers) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\gjaischool1\anaconda3\envs\deep_learning\lib\site-packages (from scikit-learn->sentence_transformers) (3.2.0)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in c:\users\gjaischool1\anaconda3\envs\deep_learning\lib\site-packages (from torchvision->sentence_transformers) (10.0.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\gjaischool1\anaconda3\envs\deep_learning\lib\site-packages (from jinja2->torch>=1.6.0->sentence_transformers) (2.1.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\gjaischool1\anaconda3\envs\deep_learning\lib\site-packages (from requests->huggingface-hub>=0.4.0->sentence_transformers) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\gjaischool1\anaconda3\envs\deep_learning\lib\site-packages (from requests->huggingface-hub>=0.4.0->sentence_transformers) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\gjaischool1\anaconda3\envs\deep_learning\lib\site-packages (from requests->huggingface-hub>=0.4.0->sentence_transformers) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\gjaischool1\anaconda3\envs\deep_learning\lib\site-packages (from requests->huggingface-hub>=0.4.0->sentence_transformers) (2023.7.22)
# Requirement already satisfied: mpmath>=0.19 in c:\users\gjaischool1\anaconda3\envs\deep_learning\lib\site-packages (from sympy->torch>=1.6.0->sentence_transformers) (1.3.0)
# Downloading torchvision-0.16.0-cp38-cp38-win_amd64.whl (1.3 MB)
#    ---------------------------------------- 0.0/1.3 MB ? eta -:--:--
#    --------------------- ------------------ 0.7/1.3 MB 21.5 MB/s eta 0:00:01
#    ------------------------------- -------- 1.0/1.3 MB 10.5 MB/s eta 0:00:01
#    ---------------------------------------- 1.3/1.3 MB 11.5 MB/s eta 0:00:00
# Downloading click-8.1.7-py3-none-any.whl (97 kB)
#    ---------------------------------------- 0.0/97.9 kB ? eta -:--:--
#    ---------------------------------------- 97.9/97.9 kB ? eta 0:00:00
# Building wheels for collected packages: sentence_transformers
#   Building wheel for sentence_transformers (setup.py): started
#   Building wheel for sentence_transformers (setup.py): finished with status 'done'
#   Created wheel for sentence_transformers: filename=sentence_transformers-2.2.2-py3-none-any.whl size=125960 sha256=776b5104a6b1a8e22784f394e61e5d17c9264d0bf17187a16f99c05a1f8d9228
#   Stored in directory: c:\users\gjaischool1\appdata\local\pip\cache\wheels\5e\6f\8c\d88aec621f3f542d26fac0342bef5e693335d125f4e54aeffe
# Successfully built sentence_transformers
# Installing collected packages: sentencepiece, click, nltk, torchvision, sentence_transformers
# Successfully installed click-8.1.7 nltk-3.8.1 sentence_transformers-2.2.2 sentencepiece-0.1.99 torchvision-0.16.0
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np
import pandas as pd
from numpy import dot
from numpy.linalg import norm
import urllib.request
from sentence_transformers import SentenceTransformer

# %%
urllib.request.urlretrieve("https://raw.githubusercontent.com/songys/Chatbot_data/master/ChatbotData.csv", filename="ChatBotData.csv")
train_data = pd.read_csv('ChatBotData.csv')
train_data.head()
# Out:
#                  Q            A  label
# 0           12시 땡!   하루가 또 가네요.      0
# 1      1지망 학교 떨어졌어    위로해 드립니다.      0
# 2     3박4일 놀러가고 싶다  여행은 언제나 좋죠.      0
# 3  3박4일 정도 놀러가고 싶다  여행은 언제나 좋죠.      0
# 4          PPL 심하네   눈살이 찌푸려지죠.      0

# %%
model = SentenceTransformer('sentence-transformers/xlm-r-100langs-bert-base-nli-stsb-mean-tokens')
# Out:
# Downloading (…)ab895/.gitattributes:   0%|          | 0.00/574 [00:00<?, ?B/s]
# Downloading (…)_Pooling/config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]
# Downloading (…)f9e99ab895/README.md:   0%|          | 0.00/4.06k [00:00<?, ?B/s]
# Downloading (…)e99ab895/config.json:   0%|          | 0.00/731 [00:00<?, ?B/s]
# Downloading (…)ce_transformers.json:   0%|          | 0.00/122 [00:00<?, ?B/s]
# Downloading pytorch_model.bin:   0%|          | 0.00/1.11G [00:00<?, ?B/s]
# Downloading (…)nce_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# Downloading (…)tencepiece.bpe.model:   0%|          | 0.00/5.07M [00:00<?, ?B/s]
# Downloading (…)cial_tokens_map.json:   0%|          | 0.00/150 [00:00<?, ?B/s]
# Downloading tokenizer.json:   0%|          | 0.00/9.10M [00:00<?, ?B/s]
# Downloading (…)okenizer_config.json:   0%|          | 0.00/527 [00:00<?, ?B/s]
# Downloading (…)99ab895/modules.json:   0%|          | 0.00/229 [00:00<?, ?B/s]

# %%
train_data['embedding'] = train_data.apply(lambda row: model.encode(row.Q), axis = 1)

# %%
def cos_sim(A, B):
  return dot(A, B)/(norm(A)*norm(B))

# %%
def return_answer(question):
    embedding = model.encode(question)
    train_data['score'] = train_data.apply(lambda x: cos_sim(x['embedding'], embedding), axis=1)
    return train_data.loc[train_data['score'].idxmax()]['A']

# %%
return_answer('바보')
# Out:
# '스스로 비난하지 마요.'

# %%
return_answer('죽을래?')
# Out:
# '저는 오래 살고 싶어요.'

# %%
return_answer('개xx')
# Out:
# '아이구'

# %%
return_answer('시1111발')
# Out:
# '감성적인 시간이네요.'
